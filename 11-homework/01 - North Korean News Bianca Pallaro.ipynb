# %% [markdown]
# # North Korean News
#
# Scrape the North Korean news agency http://kcna.kp
#
# Save a CSV called `nk-news.csv`. This file should include:
#
# * The **article headline**
# * The value of **`onclick`** (they don't have normal links)
# * The **article ID** (for example, the article ID for `fn_showArticle("AR0125885", "", "NT00", "L")` is `AR0125885`
#
# The last part is easiest using pandas. Be sure you don't save the index!
#
# * _**Tip:** If you're using requests+BeautifulSoup, you can always look at response.text to see if the page looks like what you think it looks like_
# * _**Tip:** Check your URL to make sure it is what you think it should be!_
# * _**Tip:** Does it look different if you scrape with BeautifulSoup compared to if you scrape it with Selenium?_
# * _**Tip:** For the last part, how do you pull out part of a string from a longer string?_
# * _**Tip:** `expand=False` is helpful if you want to assign a single new column when extracting_
# * _**Tip:** `(` and `)` mean something special in regular expressions, so you have to say "no really seriously I mean `(`" by using `\(` instead_
# * _**Tip:** if your `.*` is taking up too much stuff, you can try `.*?` instead, which instead of "take as much as possible" it means "take only as much as needed"_

# %%
import requests

from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get("http://kcna.kp/kcna.user.home.retrieveHomeInfoList.kcmsf;jsessionid=99311A250357D4ADC047F4970E1D284C")

# %%
headlines = driver.find_elements_by_class_name("titlebet")
for headline in headlines:
    print(headline.text.strip())
# Out:
# Pyongyang Bag Factory
# Autumn Ploughing Finishes in DPRK
# Tanchon City
# Overhaul of Irrigation Facilities Brisk in DPRK
# Boost in Greenhouse Vegetable Production Witnessed in DPRK
# Monthly Plans Fulfilled in Various Economic Sectors
# Top-class Emergency Anti-epidemic Measures Taken across DPRK
# Thaechon Terrapin Farm Inaugurated
# Many Youth Workteams Reap Bumper Harvests in DPRK
# Tongraegang Reservoir Completed in DPRK
# 4th Session of 14th SPA to Be Convened
# 12th Plenary Meeting of 14th Presidium of DPRK Supreme People's Assembly Held
# DPRK Premier Inspects Various Industrial Establishments
# Socialist Fairyland Villages Appeared in Komdok Area of South Hamgyong Province
# New Hostel Built in Sinuiju Textile Mill
# Supreme Leader Kim Jong Un Receives Reply Message from Syrian President
# People Move to New Dwelling Houses in Orang and Hochon Counties
# Heroic Myth Created in Rehabilitation Campaign in North, South Hamgyong Provinces
# Heroic Feats Performed by Divisions of Elite Party Members from Capital City Will Shine Long in History of Our Party
# Meeting of Members of Divisions of Party Members from Capital City Held
# Olympic Gold Medalists in DPRK (11)
# Paduk Encouraged in DPRK
# Scores of Achievements Made by Academy of Sports Science
# Taekwon-Do, Orthodox Martial Art of Korean Nation
# Olympic Gold Medalists in DPRK (10)
# Patriotic Veterinary Scientist
# Academy of Agricultural Science
#
# Pyongyang Bag Factory
#
#
# Supreme Leader Kim Jong Un Sends Greetings to Laotian President
# Enlarged Meeting of 21st Political Bureau of 7th Central Committee of WPK Held
# Supreme Leader Kim Jong Un Sends Greetings to Syrian President
# 20th Enlarged Meeting of Political Bureau of 7th Central Committee of WPK Held
# Supreme Leader Kim Jong Un Sends Congratulatory Message to Participants in Conference of Representatives of Branches of Chongryon-2020 (Third Conference of a New Heyday)
# Supreme Leader Kim Jong Un Sends Wreath to Bier of Late Ra Myong Hui
# Enlarged Edition Vol. 12 of "Complete Collection of Kim Il Sung's Works" Published
# Pyongyang Bag Factory
# Autumn Ploughing Finishes in DPRK
# Technological Innovation Movement Gains Momentum in DPRK
# DPRK Ambassador Presents Credentials to Slovak President
# Tanchon City
# Press Review
# Efforts for Protecting Ecological Environment Brisk in DPRK
# Movement for Winning Title of Forest of Socialist Patriotism Brisk in DPRK
# Overhaul of Irrigation Facilities Brisk in DPRK
# 4th Session of 14th SPA to Be Convened
# 12th Plenary Meeting of 14th Presidium of DPRK Supreme People's Assembly Held
# Effective Therapies for Cancer Studied
# Japanese Regime Accused of Discrimination against Korean Schools
# Remains of Martyrs Buried in Patriotic Martyrs Cemetery in Sinmi-ri
# Hoeryong White Apricot
# Grand People's Study House
# Korean Nation's Superior Stone Sculpture
# Study tour of Mt Paektu
# Rodong Sinmun Calls for Embodying Spirit of Mt Paektu in Production of Masterpieces
# Press Review
# Kwangbop Temple
# Advanced Treatment Methods Introduced in DPRK
# DPRK Students Prove Successful at Int'l Software Contest
# Illustrated Book on Historical Sites and Relics
# Protection of Disabled Persons in DPRK
# Greetings to Laotian PM
# Pubyok Pavilion
# Samjiyon Blueberry Drink Factory
# Olympic Gold Medalists in DPRK (11)
# DPRK Ambassador Presents Credentials to Slovak President
# Greetings to Laotian PM
# Congratulations to Syrian FM
# Supreme Leader Kim Jong Un Receives Reply Message from Syrian President
# Greetings to Lebanese Minister of Foreign Affairs and Immigrants
# DPRK Ambassador Presents Credentials to President of South Africa
# Greetings to Palestinian Minister of Foreign Affairs and Expatriates
# Congratulations to Ethiopian FM
# DPRK Ambassador Presents Credentials to Slovak President
# Japanese Regime Accused of Discrimination against Korean Schools
# Supreme Leader Kim Jong Un Receives Reply Message from Syrian President
# Suicide Is Intractable Problem in Japan
# Koreans in Japan Protest Japanese Court's Unreasonable Judgment
# Letter to Supreme Leader Kim Jong Un from Participants in Conference of Representatives of Branches of Chongryon-2020
# Koreans Forced into Slave Labor by Japanese Imperialists
# DPRK Ambassador Presents Credentials to President of South Africa
# Credentials to President of Belarus
# Conference of Representatives of Branches of Chongryon-2020 Held
# WPK Founding Anniversary Marked Abroad
# S. Korean Authorities Warned against Intrusion
# Japan Urged to Acknowledge Mass Killings of Koreans
# 8th Congress of WPK to Be Convened
# Statement of Korean Committee on Measures for Sexual Slavery for Japanese Army and Drafting Victims
# New Premier of DPRK Cabinet Appointed
# Answer of Spokesperson for DPRK Foreign Ministry
# Press Statement by Kim Yo Jong, First Vice Department Director of Central Committee of Workers' Party of Korea

# %%
headlines = driver.find_elements_by_class_name("titlebet")
for headline in headlines:
    print(headline.get_attribute('onclick'))
# Out:
# fn_showArticle("AR0140387", "", "NT60", "L")
# fn_showArticle("AR0140401", "", "NT60", "L")
# fn_showArticle("AR0140379", "", "NT60", "L")
# fn_showArticle("AR0140383", "", "NT60", "L")
# fn_showArticle("AR0140324", "", "NT60", "L")
# fn_showArticle("AR0140311", "", "NT60", "L")
# fn_showArticle("AR0140310", "", "NT60", "L")
# fn_showArticle("AR0140298", "", "NT60", "L")
# fn_showArticle("AR0140297", "", "NT60", "L")
# fn_showArticle("AR0140274", "", "NT60", "L")
# fn_showArticle("AR0140382", "", "NT21", "L")
# fn_showArticle("AR0140381", "", "NT21", "L")
# fn_showArticle("AR0140240", "", "NT21", "L")
# fn_showArticle("AR0140195", "", "NT21", "L")
# fn_showArticle("AR0140176", "", "NT21", "L")
# fn_showArticle("AR0140127", "", "NT21", "L")
# fn_showArticle("AR0140109", "", "NT21", "L")
# fn_showArticle("AR0140088", "", "NT21", "L")
# fn_showArticle("AR0140065", "", "NT21", "L")
# fn_showArticle("AR0140067", "", "NT21", "L")
# fn_showArticle("AR0140332", "", "NT11", "L")
# fn_showArticle("AR0140315", "", "NT11", "L")
# fn_showArticle("AR0140250", "", "NT11", "L")
# fn_showArticle("AR0140182", "", "NT11", "L")
# fn_showArticle("AR0140181", "", "NT11", "L")
# fn_showArticle("AR0140165", "", "NT09", "L")
# fn_showArticle("AR0139626", "", "NT09", "L")
# fn_showArticle("AR0140387", "", "NT10", "L")
# fn_showArticle("AR0140379", "", "NT10", "L")
# fn_showArticle("AR0140341", "", "NT10", "L")
# fn_showArticle("AR0140316", "", "NT10", "L")
# fn_showArticle("AR0140322", "", "NT00", "L")
# fn_showArticle("AR0140253", "", "NT00", "L")
# fn_showArticle("AR0139989", "", "NT00", "L")
# fn_showArticle("AR0139950", "", "NT00", "L")
# fn_showArticle("AR0139645", "", "NT00", "L")
# fn_showArticle("AR0139638", "", "NT00", "L")
# fn_showArticle("AR0140415", "", "NT41", "L")
# fn_showArticle("AR0140387", "", "NT41", "L")
# fn_showArticle("AR0140401", "", "NT41", "L")
# fn_showArticle("AR0140400", "", "NT41", "L")
# fn_showArticle("AR0140399", "", "NT41", "L")
# fn_showArticle("AR0140379", "", "NT41", "L")
# fn_showArticle("AR0140386", "", "NT41", "L")
# fn_showArticle("AR0140385", "", "NT41", "L")
# fn_showArticle("AR0140384", "", "NT41", "L")
# fn_showArticle("AR0140383", "", "NT41", "L")
# fn_showArticle("AR0140382", "", "NT41", "L")
# fn_showArticle("AR0140381", "", "NT41", "L")
# fn_showArticle("AR0140356", "", "NT41", "L")
# fn_showArticle("AR0140350", "", "NT41", "L")
# fn_showArticle("AR0140380", "", "NT41", "L")
# fn_showArticle("AR0140373", "", "NT41", "L")
# fn_showArticle("AR0140341", "", "NT41", "L")
# fn_showArticle("AR0140372", "", "NT41", "L")
# fn_showArticle("AR0140340", "", "NT41", "L")
# fn_showArticle("AR0140360", "", "NT41", "L")
# fn_showArticle("AR0140358", "", "NT41", "L")
# fn_showArticle("AR0140357", "", "NT41", "L")
# fn_showArticle("AR0140355", "", "NT41", "L")
# fn_showArticle("AR0140354", "", "NT41", "L")
# fn_showArticle("AR0140352", "", "NT41", "L")
# fn_showArticle("AR0140351", "", "NT41", "L")
# fn_showArticle("AR0140349", "", "NT41", "L")
# fn_showArticle("AR0140342", "", "NT41", "L")
# fn_showArticle("AR0140316", "", "NT41", "L")
# fn_showArticle("AR0140332", "", "NT41", "L")
# fn_showArticle("AR0140399", "", "NT03", "L")
# fn_showArticle("AR0140349", "", "NT03", "L")
# fn_showArticle("AR0140162", "", "NT03", "L")
# fn_showArticle("AR0140127", "", "NT03", "L")
# fn_showArticle("AR0140108", "", "NT03", "L")
# fn_showArticle("AR0140086", "", "NT03", "L")
# fn_showArticle("AR0139944", "", "NT03", "L")
# fn_showArticle("AR0139907", "", "NT03", "L")
# fn_showArticle("AR0140399", "", "NT06", "L")
# fn_showArticle("AR0140350", "", "NT06", "L")
# fn_showArticle("AR0140127", "", "NT06", "L")
# fn_showArticle("AR0139866", "", "NT06", "L")
# fn_showArticle("AR0139737", "", "NT06", "L")
# fn_showArticle("AR0139722", "", "NT06", "L")
# fn_showArticle("AR0140326", "", "NT06", "L")
# fn_showArticle("AR0140086", "", "NT06", "L")
# fn_showArticle("AR0139742", "", "NT06", "L")
# fn_showArticle("AR0139723", "", "NT06", "L")
# fn_showArticle("AR0139648", "", "NT06", "L")
# fn_showArticle("AR0138770", "", "NT17", "L")
# fn_showArticle("AR0138016", "", "NT17", "L")
# fn_showArticle("AR0137942", "", "NT17", "L")
# fn_showArticle("AR0137826", "", "NT17", "L")
# fn_showArticle("AR0137794", "", "NT17", "L")
# fn_showArticle("AR0137273", "", "NT17", "L")
# fn_showArticle("AR0137160", "", "NT17", "L")
# fn_showArticle("AR0140386", "", "NT16", "L")
# fn_showArticle("AR0140360", "", "NT16", "L")
# fn_showArticle("AR0140358", "", "NT16", "L")
# fn_showArticle("AR0140329", "", "NT16", "L")
# fn_showArticle("AR0140328", "", "NT16", "L")
# fn_showArticle("AR0140301", "", "NT16", "L")
# fn_showArticle("AR0140300", "", "NT16", "L")
# fn_showArticle("AR0139094", "", "NT02", "L")

# %%
articles = []

headlines = driver.find_elements_by_class_name("titlebet")
for headline in headlines:
        url = headline.get_attribute('onclick')
        headline = headline.text.strip()
        article = {
            'headline': headline,
            'url': url
        }
        articles.append(article)

articles
# Out:
# [{'headline': 'Pyongyang Bag Factory',
#   'url': 'fn_showArticle("AR0140387", "", "NT60", "L")'},
#  {'headline': 'Autumn Ploughing Finishes in DPRK',
#   'url': 'fn_showArticle("AR0140401", "", "NT60", "L")'},
#  {'headline': 'Tanchon City',
#   'url': 'fn_showArticle("AR0140379", "", "NT60", "L")'},
#  {'headline': 'Overhaul of Irrigation Facilities Brisk in DPRK',
#   'url': 'fn_showArticle("AR0140383", "", "NT60", "L")'},
#  {'headline': 'Boost in Greenhouse Vegetable Production Witnessed in DPRK',
#   'url': 'fn_showArticle("AR0140324", "", "NT60", "L")'},
#  {'headline': 'Monthly Plans Fulfilled in Various Economic Sectors',
#   'url': 'fn_showArticle("AR0140311", "", "NT60", "L")'},
#  {'headline': 'Top-class Emergency Anti-epidemic Measures Taken across DPRK',
#   'url': 'fn_showArticle("AR0140310", "", "NT60", "L")'},
#  {'headline': 'Thaechon Terrapin Farm Inaugurated',
#   'url': 'fn_showArticle("AR0140298", "", "NT60", "L")'},
#  {'headline': 'Many Youth Workteams Reap Bumper Harvests in DPRK',
#   'url': 'fn_showArticle("AR0140297", "", "NT60", "L")'},
#  {'headline': 'Tongraegang Reservoir Completed in DPRK',
#   'url': 'fn_showArticle("AR0140274", "", "NT60", "L")'},
#  {'headline': '4th Session of 14th SPA to Be Convened',
#   'url': 'fn_showArticle("AR0140382", "", "NT21", "L")'},
#  {'headline': "12th Plenary Meeting of 14th Presidium of DPRK Supreme People's Assembly Held",
#   'url': 'fn_showArticle("AR0140381", "", "NT21", "L")'},
#  {'headline': 'DPRK Premier Inspects Various Industrial Establishments',
#   'url': 'fn_showArticle("AR0140240", "", "NT21", "L")'},
#  {'headline': 'Socialist Fairyland Villages Appeared in Komdok Area of South Hamgyong Province',
#   'url': 'fn_showArticle("AR0140195", "", "NT21", "L")'},
#  {'headline': 'New Hostel Built in Sinuiju Textile Mill',
#   'url': 'fn_showArticle("AR0140176", "", "NT21", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Receives Reply Message from Syrian President',
#   'url': 'fn_showArticle("AR0140127", "", "NT21", "L")'},
#  {'headline': 'People Move to New Dwelling Houses in Orang and Hochon Counties',
#   'url': 'fn_showArticle("AR0140109", "", "NT21", "L")'},
#  {'headline': 'Heroic Myth Created in Rehabilitation Campaign in North, South Hamgyong Provinces',
#   'url': 'fn_showArticle("AR0140088", "", "NT21", "L")'},
#  {'headline': 'Heroic Feats Performed by Divisions of Elite Party Members from Capital City Will Shine Long in History of Our Party',
#   'url': 'fn_showArticle("AR0140065", "", "NT21", "L")'},
#  {'headline': 'Meeting of Members of Divisions of Party Members from Capital City Held',
#   'url': 'fn_showArticle("AR0140067", "", "NT21", "L")'},
#  {'headline': 'Olympic Gold Medalists in DPRK (11)',
#   'url': 'fn_showArticle("AR0140332", "", "NT11", "L")'},
#  {'headline': 'Paduk Encouraged in DPRK',
#   'url': 'fn_showArticle("AR0140315", "", "NT11", "L")'},
#  {'headline': 'Scores of Achievements Made by Academy of Sports Science',
#   'url': 'fn_showArticle("AR0140250", "", "NT11", "L")'},
#  {'headline': 'Taekwon-Do, Orthodox Martial Art of Korean Nation',
#   'url': 'fn_showArticle("AR0140182", "", "NT11", "L")'},
#  {'headline': 'Olympic Gold Medalists in DPRK (10)',
#   'url': 'fn_showArticle("AR0140181", "", "NT11", "L")'},
#  {'headline': 'Patriotic Veterinary Scientist',
#   'url': 'fn_showArticle("AR0140165", "", "NT09", "L")'},
#  {'headline': 'Academy of Agricultural Science',
#   'url': 'fn_showArticle("AR0139626", "", "NT09", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140341", "", "NT10", "L")'},
#  {'headline': 'Samjiyon Blueberry Drink Factory',
#   'url': 'fn_showArticle("AR0140316", "", "NT10", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140387", "", "NT10", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140379", "", "NT10", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Sends Greetings to Laotian President',
#   'url': 'fn_showArticle("AR0140322", "", "NT00", "L")'},
#  {'headline': 'Enlarged Meeting of 21st Political Bureau of 7th Central Committee of WPK Held',
#   'url': 'fn_showArticle("AR0140253", "", "NT00", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Sends Greetings to Syrian President',
#   'url': 'fn_showArticle("AR0139989", "", "NT00", "L")'},
#  {'headline': '20th Enlarged Meeting of Political Bureau of 7th Central Committee of WPK Held',
#   'url': 'fn_showArticle("AR0139950", "", "NT00", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Sends Congratulatory Message to Participants in Conference of Representatives of Branches of Chongryon-2020 (Third Conference of a New Heyday)',
#   'url': 'fn_showArticle("AR0139645", "", "NT00", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Sends Wreath to Bier of Late Ra Myong Hui',
#   'url': 'fn_showArticle("AR0139638", "", "NT00", "L")'},
#  {'headline': 'Enlarged Edition Vol. 12 of "Complete Collection of Kim Il Sung\'s Works" Published',
#   'url': 'fn_showArticle("AR0140415", "", "NT41", "L")'},
#  {'headline': 'Pyongyang Bag Factory',
#   'url': 'fn_showArticle("AR0140387", "", "NT41", "L")'},
#  {'headline': 'Autumn Ploughing Finishes in DPRK',
#   'url': 'fn_showArticle("AR0140401", "", "NT41", "L")'},
#  {'headline': 'Technological Innovation Movement Gains Momentum in DPRK',
#   'url': 'fn_showArticle("AR0140400", "", "NT41", "L")'},
#  {'headline': 'DPRK Ambassador Presents Credentials to Slovak President',
#   'url': 'fn_showArticle("AR0140399", "", "NT41", "L")'},
#  {'headline': 'Tanchon City',
#   'url': 'fn_showArticle("AR0140379", "", "NT41", "L")'},
#  {'headline': 'Press Review',
#   'url': 'fn_showArticle("AR0140386", "", "NT41", "L")'},
#  {'headline': 'Efforts for Protecting Ecological Environment Brisk in DPRK',
#   'url': 'fn_showArticle("AR0140385", "", "NT41", "L")'},
#  {'headline': 'Movement for Winning Title of Forest of Socialist Patriotism Brisk in DPRK',
#   'url': 'fn_showArticle("AR0140384", "", "NT41", "L")'},
#  {'headline': 'Overhaul of Irrigation Facilities Brisk in DPRK',
#   'url': 'fn_showArticle("AR0140383", "", "NT41", "L")'},
#  {'headline': '4th Session of 14th SPA to Be Convened',
#   'url': 'fn_showArticle("AR0140382", "", "NT41", "L")'},
#  {'headline': "12th Plenary Meeting of 14th Presidium of DPRK Supreme People's Assembly Held",
#   'url': 'fn_showArticle("AR0140381", "", "NT41", "L")'},
#  {'headline': 'Effective Therapies for Cancer Studied',
#   'url': 'fn_showArticle("AR0140356", "", "NT41", "L")'},
#  {'headline': 'Japanese Regime Accused of Discrimination against Korean Schools',
#   'url': 'fn_showArticle("AR0140350", "", "NT41", "L")'},
#  {'headline': 'Remains of Martyrs Buried in Patriotic Martyrs Cemetery in Sinmi-ri',
#   'url': 'fn_showArticle("AR0140380", "", "NT41", "L")'},
#  {'headline': 'Hoeryong White Apricot',
#   'url': 'fn_showArticle("AR0140373", "", "NT41", "L")'},
#  {'headline': "Grand People's Study House",
#   'url': 'fn_showArticle("AR0140341", "", "NT41", "L")'},
#  {'headline': "Korean Nation's Superior Stone Sculpture",
#   'url': 'fn_showArticle("AR0140372", "", "NT41", "L")'},
#  {'headline': 'Study tour of Mt Paektu',
#   'url': 'fn_showArticle("AR0140340", "", "NT41", "L")'},
#  {'headline': 'Rodong Sinmun Calls for Embodying Spirit of Mt Paektu in Production of Masterpieces',
#   'url': 'fn_showArticle("AR0140360", "", "NT41", "L")'},
#  {'headline': 'Press Review',
#   'url': 'fn_showArticle("AR0140358", "", "NT41", "L")'},
#  {'headline': 'Kwangbop Temple',
#   'url': 'fn_showArticle("AR0140357", "", "NT41", "L")'},
#  {'headline': 'Advanced Treatment Methods Introduced in DPRK',
#   'url': 'fn_showArticle("AR0140355", "", "NT41", "L")'},
#  {'headline': "DPRK Students Prove Successful at Int'l Software Contest",
#   'url': 'fn_showArticle("AR0140354", "", "NT41", "L")'},
#  {'headline': 'Illustrated Book on Historical Sites and Relics',
#   'url': 'fn_showArticle("AR0140352", "", "NT41", "L")'},
#  {'headline': 'Protection of Disabled Persons in DPRK',
#   'url': 'fn_showArticle("AR0140351", "", "NT41", "L")'},
#  {'headline': 'Greetings to Laotian PM',
#   'url': 'fn_showArticle("AR0140349", "", "NT41", "L")'},
#  {'headline': 'Pubyok Pavilion',
#   'url': 'fn_showArticle("AR0140342", "", "NT41", "L")'},
#  {'headline': 'Samjiyon Blueberry Drink Factory',
#   'url': 'fn_showArticle("AR0140316", "", "NT41", "L")'},
#  {'headline': 'Olympic Gold Medalists in DPRK (11)',
#   'url': 'fn_showArticle("AR0140332", "", "NT41", "L")'},
#  {'headline': 'DPRK Ambassador Presents Credentials to Slovak President',
#   'url': 'fn_showArticle("AR0140399", "", "NT03", "L")'},
#  {'headline': 'Greetings to Laotian PM',
#   'url': 'fn_showArticle("AR0140349", "", "NT03", "L")'},
#  {'headline': 'Congratulations to Syrian FM',
#   'url': 'fn_showArticle("AR0140162", "", "NT03", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Receives Reply Message from Syrian President',
#   'url': 'fn_showArticle("AR0140127", "", "NT03", "L")'},
#  {'headline': 'Greetings to Lebanese Minister of Foreign Affairs and Immigrants',
#   'url': 'fn_showArticle("AR0140108", "", "NT03", "L")'},
#  {'headline': 'DPRK Ambassador Presents Credentials to President of South Africa',
#   'url': 'fn_showArticle("AR0140086", "", "NT03", "L")'},
#  {'headline': 'Greetings to Palestinian Minister of Foreign Affairs and Expatriates',
#   'url': 'fn_showArticle("AR0139944", "", "NT03", "L")'},
#  {'headline': 'Congratulations to Ethiopian FM',
#   'url': 'fn_showArticle("AR0139907", "", "NT03", "L")'},
#  {'headline': 'DPRK Ambassador Presents Credentials to Slovak President',
#   'url': 'fn_showArticle("AR0140399", "", "NT06", "L")'},
#  {'headline': 'Japanese Regime Accused of Discrimination against Korean Schools',
#   'url': 'fn_showArticle("AR0140350", "", "NT06", "L")'},
#  {'headline': 'Supreme Leader Kim Jong Un Receives Reply Message from Syrian President',
#   'url': 'fn_showArticle("AR0140127", "", "NT06", "L")'},
#  {'headline': 'Suicide Is Intractable Problem in Japan',
#   'url': 'fn_showArticle("AR0139866", "", "NT06", "L")'},
#  {'headline': "Koreans in Japan Protest Japanese Court's Unreasonable Judgment",
#   'url': 'fn_showArticle("AR0139737", "", "NT06", "L")'},
#  {'headline': 'Letter to Supreme Leader Kim Jong Un from Participants in Conference of Representatives of Branches of Chongryon-2020',
#   'url': 'fn_showArticle("AR0139722", "", "NT06", "L")'},
#  {'headline': 'Koreans Forced into Slave Labor by Japanese Imperialists',
#   'url': 'fn_showArticle("AR0140326", "", "NT06", "L")'},
#  {'headline': 'DPRK Ambassador Presents Credentials to President of South Africa',
#   'url': 'fn_showArticle("AR0140086", "", "NT06", "L")'},
#  {'headline': 'Credentials to President of Belarus',
#   'url': 'fn_showArticle("AR0139742", "", "NT06", "L")'},
#  {'headline': 'Conference of Representatives of Branches of Chongryon-2020 Held',
#   'url': 'fn_showArticle("AR0139723", "", "NT06", "L")'},
#  {'headline': 'WPK Founding Anniversary Marked Abroad',
#   'url': 'fn_showArticle("AR0139648", "", "NT06", "L")'},
#  {'headline': 'S. Korean Authorities Warned against Intrusion',
#   'url': 'fn_showArticle("AR0138770", "", "NT17", "L")'},
#  {'headline': 'Japan Urged to Acknowledge Mass Killings of Koreans',
#   'url': 'fn_showArticle("AR0138016", "", "NT17", "L")'},
#  {'headline': '8th Congress of WPK to Be Convened',
#   'url': 'fn_showArticle("AR0137942", "", "NT17", "L")'},
#  {'headline': 'Statement of Korean Committee on Measures for Sexual Slavery for Japanese Army and Drafting Victims',
#   'url': 'fn_showArticle("AR0137826", "", "NT17", "L")'},
#  {'headline': 'New Premier of DPRK Cabinet Appointed',
#   'url': 'fn_showArticle("AR0137794", "", "NT17", "L")'},
#  {'headline': 'Answer of Spokesperson for DPRK Foreign Ministry',
#   'url': 'fn_showArticle("AR0137273", "", "NT17", "L")'},
#  {'headline': "Press Statement by Kim Yo Jong, First Vice Department Director of Central Committee of Workers' Party of Korea",
#   'url': 'fn_showArticle("AR0137160", "", "NT17", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140386", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140360", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140358", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140329", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140328", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140301", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0140300", "", "NT16", "L")'},
#  {'headline': '', 'url': 'fn_showArticle("AR0139094", "", "NT02", "L")'}]

# %%
import pandas as pd

df = pd.DataFrame(articles)
df.head()
# Out:
#                                             headline  \
# 0                              Pyongyang Bag Factory
# 1                  Autumn Ploughing Finishes in DPRK
# 2                                       Tanchon City
# 3    Overhaul of Irrigation Facilities Brisk in DPRK
# 4  Boost in Greenhouse Vegetable Production Witne...
#
#                                             url
# 0  fn_showArticle("AR0140387", "", "NT60", "L")
# 1  fn_showArticle("AR0140401", "", "NT60", "L")
# 2  fn_showArticle("AR0140379", "", "NT60", "L")
# 3  fn_showArticle("AR0140383", "", "NT60", "L")
# 4  fn_showArticle("AR0140324", "", "NT60", "L")

# %%
df['id'] = df.url.str.extract(r'(\w\w\d\d\d\d\d\d\d)')
df.head()
# Out:
#                                             headline  \
# 0                              Pyongyang Bag Factory
# 1                  Autumn Ploughing Finishes in DPRK
# 2                                       Tanchon City
# 3    Overhaul of Irrigation Facilities Brisk in DPRK
# 4  Boost in Greenhouse Vegetable Production Witne...
#
#                                             url         id
# 0  fn_showArticle("AR0140387", "", "NT60", "L")  AR0140387
# 1  fn_showArticle("AR0140401", "", "NT60", "L")  AR0140401
# 2  fn_showArticle("AR0140379", "", "NT60", "L")  AR0140379
# 3  fn_showArticle("AR0140383", "", "NT60", "L")  AR0140383
# 4  fn_showArticle("AR0140324", "", "NT60", "L")  AR0140324

# %%
df.to_csv(r'/Users/biancapallaro/Documents/Foundations/north_korea.csv', index = False, header=True)
